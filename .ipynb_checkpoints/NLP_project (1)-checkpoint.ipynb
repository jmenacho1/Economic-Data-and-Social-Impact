# %%
# Initial imports
import os
from pathlib import Path
import pandas as pd
from newsapi import NewsApiClient
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
nltk.download('vader_lexicon')            # need this for sentiment analyzer further down in code
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\james\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# api_key ='c5c492da6d534f529f2d9c386c8f500f'  ##sasha stuff

# %%
# api_key = "NEWS_API_KEY"  # me doin stuff

# %%
# api_key = os.getenv("QUANDL_API_KEY")    # garence stuff

# %%
key = os.getenv("NEWS_API_KEY")   # garence stuff

# %%
# Verify variable type

type(key)
# Out:
# str

# %%
# Verify Key connectivity

(key)
# Out:
# 'c1663debb8fa46dba0048fd4c8d88a49'

# %%
newsapi = NewsApiClient(api_key=key)
# newsapi = NewsApiClient(api_key=NEWS_API_KEY)
# newsapi = NewsApiClient(NEWS_API_KEY=api_key)

# %%
refinery_headlines = newsapi.get_everything(             # this works
    q="storm" and "refinery outage",
    language="en",
)

print(f"Total articles about refinery headlines: {shooting_headlines['totalResults']}")


refinery_headlines["articles"]
# Out:
# Total articles about refinery headlines: 28
# [{'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'California diesel, jet prices rise on Chevron hydrotreater outage -trade - Reuters',
#   'description': 'California diesel prices climbed 52.5 cents a gallon this week in the San Francisco Bay market because of a hydrotreater outage at Chevron Corp’s <a href="https://www.reuters.com/companies/CVX.N" target="_blank">(CVX.N)</a> Richmond, California, refinery, sai…',
#   'url': 'https://www.reuters.com/business/energy/california-diesel-jet-prices-rise-chevron-hydrotreater-outage-trade-2022-03-25/',
#   'urlToImage': 'https://www.reuters.com/resizer/A19XoPsXF1dbZWI2xNRrWmaMdSE=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/UJ5AOSVIABJLPI3OHMAEC2R5KI.jpg',
#   'publishedAt': '2022-03-25T22:22:00Z',
# ...

# %%
# create sentiment score & store it in df:
text_sentiment = []

for article in refinery_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        text_sentiment.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
    except AttributeError:
        pass

# %%
# The sum of pos, neg, neu intensities give 1. 
# Compound ranges from -1 to 1 and is the metric used to draw the overall sentiment.
  # positive if compound >= 0.5
  # neutral if -0.5 < compound < 0.5
  # negative if -0.5 >= compound

sentiment
# Out:
# {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'compound': 0.3612}

# %%
# Visualize results in a dataframe

df=pd.DataFrame(text_sentiment)
df
# Out:
#                                                  text                  date  \
# 0   HOUSTON, March 25 (Reuters) - California diese...  2022-03-25T22:22:00Z
# 1   March 31 (Reuters) - Major Russian oil refiner...  2022-03-31T09:01:00Z
# 2   Multiple US government agencies issued a joint...  2022-04-14T01:12:58Z
# 3   HOUSTON (Reuters) - California diesel prices c...  2022-03-25T22:22:36Z
# 4                      THEGIFT777/E+ via Getty Images  2022-03-30T18:45:51Z
# 5   Extreme Media / iStock.com\r\nCalifornians don...  2022-03-24T16:17:51Z
# 6   Jorge Garcia fills up his tank at Costco in Az...  2022-04-12T18:05:19Z
# 7   Jorge Garcia fills up his tank at Costco in Az...  2022-04-12T18:05:19Z
# 8   Texas has expanded storage for natural gas and...  2022-04-09T12:00:38Z
# 9   Californians are traveling to Mexico for cheap...  2022-03-25T16:28:29Z
# 10  This past week, the U.S. government issued an ...  2022-04-17T22:57:26Z
# ...

# %%
# sort the compound values by descending score

df.sort_values(by='compound', ascending=False).head(5)
# Out:
#                                                  text                  date  \
# 2   Multiple US government agencies issued a joint...  2022-04-14T01:12:58Z
# 8   Texas has expanded storage for natural gas and...  2022-04-09T12:00:38Z
# 19  The U.S. benchmark natural gas…\r\nConsumers a...  2022-04-08T23:00:00Z
# 11  Multiple US government agencies issued a joint...  2022-04-14T11:09:40Z
# 12  Multiple U.S. government agencies issued a joi...  2022-04-14T08:26:51Z
#
#     compound  positive  negative  neutral
# 2     0.5859     0.274     0.137    0.590
# 8     0.5574     0.129     0.000    0.871
# 19    0.3612     0.072     0.000    0.928
# 11    0.2500     0.217     0.143    0.640
# 12    0.2500     0.222     0.146    0.631

# %%
# sort the compound values by asscending score

df.sort_values(by='compound', ascending=True).head(5)
# Out:
#                                                  text                  date  \
# 16  Oil prices soared Monday as a weekend attack o...  2022-03-21T14:32:08Z
# 10  This past week, the U.S. government issued an ...  2022-04-17T22:57:26Z
# 18  Russian president is likely to use cyber attac...  2022-04-05T12:41:00Z
# 1   March 31 (Reuters) - Major Russian oil refiner...  2022-03-31T09:01:00Z
# 5   Extreme Media / iStock.com\r\nCalifornians don...  2022-03-24T16:17:51Z
#
#     compound  positive  negative  neutral
# 16   -0.8271     0.046     0.267    0.687
# 10   -0.5719     0.047     0.144    0.809
# 18   -0.4404     0.000     0.081    0.919
# 1    -0.2960     0.053     0.109    0.838
# 5    -0.2551     0.000     0.109    0.891

# %%
# describe overall sentiment of dataframe:

df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.019300   0.053000   0.056800   0.890200
# std     0.344872   0.087126   0.078926   0.143948
# min    -0.827100   0.000000   0.000000   0.590000
# 25%    -0.063775   0.000000   0.000000   0.830750
# 50%     0.000000   0.000000   0.000000   0.964000
# 75%     0.062500   0.057750   0.116000   1.000000
# max     0.585900   0.274000   0.267000   1.000000

# %%
from pynytimes import NYTAPI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-d3b42fc0b8c9> in <module>
# ----> 1 from pynytimes import NYTAPI
#
# ModuleNotFoundError: No module named 'pynytimes'

# %%
nyt = NYTAPI("AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e", https=False)

# %%
top_stories = nyt.top_stories(section='science')

# %%
top_stories

# %%
import datetime

articles = nyt.article_search(
    query = "Covid19",
    results = 10,
    dates = {
        "begin": datetime.datetime(2020, 3, 1),
        "end": datetime.datetime(2020, 10, 12)
    },
    options = {
        "sort": "oldest",
        "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
        ],
        "news_desk": [
            "Politics"
        ],
        "type_of_material": [
            "News Analysis"
        ]
    }
)

# %%
import pandas as pd
from nytimesarticle import articleAPI

# %%
nyt_api_key='AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e'
api=articleAPI(nyt_api_key)
api

# %%
import os
import json
import time
import requests
import datetime
import dateutil
import pandas as pd
from dateutil.relativedelta import relativedelta

# %%
end = datetime.date.today()
start = end - relativedelta(months=7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9fff888c94e1> in <module>
# ----> 1 end = datetime.date.today()
#       2 start = end - relativedelta(months=7)
#
# NameError: name 'datetime' is not defined

# %%
months_in_range = [x.split(' ') for x in pd.date_range(start, end, freq='MS').strftime("%Y %-m").tolist()]

# %%
def send_request(date):
    '''Sends a request to the NYT Archive API for given date.'''
    base_url = 'https://api.nytimes.com/svc/archive/v1/'
    url = base_url + '/' + date[0] + '/' + date[1] + '.json?api-key=' + 'AGTGevw2BdpxCUBRjEyFC0ymAVDHVA0e'
    response = requests.get(url).json()
    time.sleep(6)
    return response


def is_valid(article, date):
    '''An article is only worth checking if it is in range, and has a headline.'''
    is_in_range = date > start and date < end
    has_headline = type(article['headline']) == dict and 'main' in article['headline'].keys()
    return is_in_range and has_headline


def parse_response(response):
    '''Parses and returns response as pandas data frame.'''
    data = {'headline': [],  
        'date': [], 
        'doc_type': [],
        'material_type': [],
        'section': [],
        'keywords': []}
    
    articles = response['response']['docs'] 
    for article in articles: # For each article, make sure it falls within our date range
        date = dateutil.parser.parse(article['pub_date']).date()
        if is_valid(article, date):
            data['date'].append(date)
            data['headline'].append(article['headline']['main']) 
            if 'section' in article:
                data['section'].append(article['section_name'])
            else:
                data['section'].append(None)
            data['doc_type'].append(article['document_type'])
            if 'type_of_material' in article: 
                data['material_type'].append(article['type_of_material'])
            else:
                data['material_type'].append(None)
            keywords = [keyword['value'] for keyword in article['keywords'] if keyword['name'] == 'subject']
            data['keywords'].append(keywords)
    return pd.DataFrame(data) 


def get_data(dates):
    '''Sends and parses request/response to/from NYT Archive API for given dates.'''
    total = 0
    print('Date range: ' + str(dates[0]) + ' to ' + str(dates[-1]))
    if not os.path.exists('headlines'):
        os.mkdir('headlines')
    for date in dates:
        response = send_request(date)
        df = parse_response(response)
        total += len(df)
        df.to_csv('headlines/' + date[0] + '-' + date[1] + '.csv', index=False)
        print('Saving headlines/' + date[0] + '-' + date[1] + '.csv...')
    print('Number of articles collected: ' + str(total))

# %%
get_data(months_in_range)

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ab0153f39f33> in <module>
# ----> 1 response
#
# NameError: name 'response' is not defined
